# %%
import dspy, os
os.environ["OPENAI_API_KEY"] = "EMPTY"  # DSPy expects a key; vLLM ignores it
lm = dspy.LM("openai/meta-llama/Llama-3.1-8B-Instruct",
             api_base="http://127.0.0.1:8000/v1")
dspy.configure(lm=lm)

# %%
class BasicQA(dspy.Signature):
    """Answer questions with short factoid answers."""

    question = dspy.InputField()
    answer = dspy.OutputField(desc="often between 1 and 5 words")

# Disable adapters so JSON mode isn't triggered
generate_answer = dspy.Predict(BasicQA, enforce_schema=False)

result = generate_answer(question="What is a fungus?")
print(result.answer)
# Out:
# A fungus is a type of organism.

# %%
class GenerateAnswer(dspy.Signature):
    """Answer questions with short factoid answers."""

    context = dspy.InputField(desc="may contain relevant facts and psychological insights")
    question = dspy.InputField()
    answer = dspy.OutputField(desc="often between 1 and 5 words")


class GenerateSearchQuery(dspy.Signature):
    """Generate a logical rule query based on the context to answer the question."""

    context = dspy.InputField(desc="may contain relevant facts and psychological insights")
    question = dspy.InputField()
    query = dspy.OutputField()


def deduplicate(seq: list[str]) -> list[str]:
    """
        From Raymond Hettinger
        https://twitter.com/raymondh/status/944125570534621185
        Since Python 3.6 Dict are ordered
        Benchmark: https://gist.github.com/peterbe/67b9e40af60a1d5bcb1cfb4b2937b088
    """
    return list(dict.fromkeys(seq))

class MultiHopSearchWithPoT(dspy.Module):
    def __init__(self, num_hops):
        self.num_hops = num_hops
        self.generate_query = dspy.ChainOfThought(GenerateSearchQuery)
        self.generate_answer = dspy.Predict(GenerateAnswer)

    def forward(self, question):
        context = []
        for _ in range(self.num_hops):
            query = self.generate_query(context=context, question=question).query
            context = deduplicate(context + [query])
        prediction = self.generate_answer(context=context, question=question)
        return dspy.Prediction(context=context, answer=prediction.answer)

# %%
multi_hop_pot = MultiHopSearchWithPoT(num_hops=2)
question = (
    "Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?",
)
multi_hop_pot(question=question).answer
# Out:
# 'Noor will serve almond milk.'

# %%
dspy.inspect_history(n=10)
# Out:
# [2025-08-14T16:24:26.244540]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `query` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## query ## ]]
# {query}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generate a logical rule query based on the context to answer the question.
#
#
# User message:
#
# [[ ## context ## ]]
# N/A
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?", "What is the belief state of Noor?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## query ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# To answer the question, we need to determine Noor's belief state regarding the contents of the milk pitcher. We can use the concept of belief revision in epistemic logic to model Noor's knowledge. Initially, Noor believes that the milk pitcher contains oat milk. However, due to the action of the coworker, the actual contents of the pitcher change to almond milk. We can represent this situation using a logical rule query.
#
# [[ ## query ## ]]
# Let's define the following predicates:
# - B(x, y): x believes y
# - C(x, y): x contains y (e.g., the milk pitcher contains oat milk)
#
# We can represent Noor's initial belief state as:
# B(Noor, C(milk_pitcher, oat_milk))
#
# After the coworker swaps the contents of the pitcher, we can represent the new situation as:
# ¬C(milk_pitcher, oat_milk) ∧ C(milk_pitcher, almond_milk)
#
# We can use the concept of belief revision to update Noor's belief state. However, since we don't have enough information about Noor's reasoning process, we can only assume that Noor will discover the change in the contents of the pitcher when they try to use it.
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:24:43.807159]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `query` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## query ## ]]
# {query}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generate a logical rule query based on the context to answer the question.
#
#
# User message:
#
# [[ ## context ## ]]
# N/A
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## query ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Noor's action will be influenced by her belief about the content of the milk pitcher. Since she believes the pitcher contains oat milk, she will likely use the milk in the pitcher to make the cappuccino. However, due to the swap by her coworker, the actual content of the pitcher is almond milk. To determine what Noor will do, we need to consider her belief and the actual state of the world.
#
# [[ ## query ## ]]
# What action will Noor take given her belief that the milk pitcher contains oat milk, but the actual content of the pitcher is almond milk?
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:24:45.363859]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `query` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## query ## ]]
# {query}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generate a logical rule query based on the context to answer the question.
#
#
# User message:
#
# [[ ## context ## ]]
# «What action will Noor take given her belief that the milk pitcher contains oat milk, but the actual content of the pitcher is almond milk?»
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## query ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Noor's action will be influenced by her belief that the milk pitcher contains oat milk. However, due to the swap by her coworker, the actual content of the pitcher is almond milk. Given Noor's belief and her intention to make a delicious cappuccino with oat milk, she will likely continue to use the milk pitcher, unaware of the swap. This is because her belief is not based on direct observation but rather on her initial action of filling the pitcher with oat milk.
#
# [[ ## query ## ]]
# What action will Noor take given her belief that the milk pitcher contains oat milk, but the actual content of the pitcher is almond milk?
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:24:45.612769]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `answer` (str): often between 1 and 5 words
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Answer questions with short factoid answers.
#
#
# User message:
#
# [[ ## context ## ]]
# «What action will Noor take given her belief that the milk pitcher contains oat milk, but the actual content of the pitcher is almond milk?»
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## answer ## ]]
# Noor will serve almond milk.
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:33:56.677408]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `query` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## query ## ]]
# {query}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generate a first order logic query based on the context to answer the question.
#
#
# User message:
#
# [[ ## context ## ]]
# N/A
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## query ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# To determine what Noor will do, we need to consider Noor's beliefs and the situation. Noor believes that the milk pitcher contains oat milk, but in reality, it contains almond milk due to the coworker's swap. This discrepancy between Noor's belief and the actual state of affairs will likely lead to an action.
#
# Given that Noor wants to make a delicious cappuccino for the customer who asked for oat milk, and Noor believes that the milk pitcher contains oat milk, Noor will likely proceed with using the milk in the pitcher, unaware of the swap. This is because Noor's belief is based on their perception of the situation, and they have no reason to doubt it.
#
# However, when Noor discovers that the cappuccino made with the milk from the pitcher does not meet the customer's request (i.e., it's not made with oat milk), Noor will likely take action to rectify the situation. This could involve informing the customer of the issue, offering a solution, or seeking assistance from a coworker.
#
# Therefore, the action Noor will take is to inform the customer that the cappuccino was made with almond milk instead of oat milk, and offer to remake the drink with the correct type of milk.
#
# [[ ## query ## ]]
# What action will Noor take when they discover that the cappuccino made with the milk from the pitcher does not meet the customer's request for oat milk?
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:33:58.791044]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `query` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## query ## ]]
# {query}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generate a first order logic query based on the context to answer the question.
#
#
# User message:
#
# [[ ## context ## ]]
# «What action will Noor take when they discover that the cappuccino made with the milk from the pitcher does not meet the customer's request for oat milk?»
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## query ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Noor will likely take action when they discover that the cappuccino made with the milk from the pitcher does not meet the customer's request for oat milk. This is because Noor wants to make a delicious cappuccino for the customer and believes that the milk pitcher contains oat milk. When they find out that it's actually almond milk, they will likely take steps to correct the situation and fulfill the customer's request.
#
# Given the context, we can infer that Noor values customer satisfaction and takes pride in their work as a barista. They will likely take action to rectify the situation, which may involve communicating with the customer, apologizing for the mistake, and offering to remake the cappuccino with the correct type of milk.
#
# [[ ## query ## ]]
# ∃x (x is an action ∧ x is taken by Noor ∧ x is to correct the cappuccino made with almond milk)
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:33:59.064180]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `answer` (str): often between 1 and 5 words
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Answer questions with short factoid answers.
#
#
# User message:
#
# [[ ## context ## ]]
# [1] «What action will Noor take when they discover that the cappuccino made with the milk from the pitcher does not meet the customer's request for oat milk?»
# [2] «∃x (x is an action ∧ x is taken by Noor ∧ x is to correct the cappuccino made with almond milk)»
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## answer ## ]]
# Noor will correct the cappuccino.
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:34:47.861742]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `query` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## query ## ]]
# {query}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generate a logical rule query based on the context to answer the question.
#
#
# User message:
#
# [[ ## context ## ]]
# N/A
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## query ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Noor's action will be influenced by her belief about the content of the milk pitcher. Since she believes the pitcher contains oat milk, she will likely use the milk in the pitcher to make the cappuccino. However, due to the swap by her coworker, the actual content of the pitcher is almond milk. To determine what Noor will do, we need to consider her belief and the actual state of the world.
#
# [[ ## query ## ]]
# What action will Noor take given her belief that the milk pitcher contains oat milk, but the actual content of the pitcher is almond milk?
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:34:47.879236]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `reasoning` (str):
# 2. `query` (str):
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## reasoning ## ]]
# {reasoning}
#
# [[ ## query ## ]]
# {query}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Generate a logical rule query based on the context to answer the question.
#
#
# User message:
#
# [[ ## context ## ]]
# «What action will Noor take given her belief that the milk pitcher contains oat milk, but the actual content of the pitcher is almond milk?»
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## reasoning ## ]]`, then `[[ ## query ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## reasoning ## ]]
# Noor's action will be influenced by her belief that the milk pitcher contains oat milk. However, due to the swap by her coworker, the actual content of the pitcher is almond milk. Given Noor's belief and her intention to make a delicious cappuccino with oat milk, she will likely continue to use the milk pitcher, unaware of the swap. This is because her belief is not based on direct observation but rather on her initial action of filling the pitcher with oat milk.
#
# [[ ## query ## ]]
# What action will Noor take given her belief that the milk pitcher contains oat milk, but the actual content of the pitcher is almond milk?
#
# [[ ## completed ## ]]
#
#
#
#
#
# [2025-08-14T16:34:47.888006]
#
# System message:
#
# Your input fields are:
# 1. `context` (str): may contain relevant facts and psychological insights
# 2. `question` (str):
# Your output fields are:
# 1. `answer` (str): often between 1 and 5 words
# All interactions will be structured in the following way, with the appropriate values filled in.
#
# [[ ## context ## ]]
# {context}
#
# [[ ## question ## ]]
# {question}
#
# [[ ## answer ## ]]
# {answer}
#
# [[ ## completed ## ]]
# In adhering to this structure, your objective is:
#         Answer questions with short factoid answers.
#
#
# User message:
#
# [[ ## context ## ]]
# «What action will Noor take given her belief that the milk pitcher contains oat milk, but the actual content of the pitcher is almond milk?»
#
# [[ ## question ## ]]
# ["Noor is working as a barista at a busy coffee shop. Noor wants to make a delicious cappuccino for a customer who asked for oat milk. Noor grabs a milk pitcher and fills it with oat milk. Noor believes that the milk pitcher contains oatmilk. A coworker, who didn't hear the customer's request, swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. What will Noor do?"]
#
# Respond with the corresponding output fields, starting with the field `[[ ## answer ## ]]`, and then ending with the marker for `[[ ## completed ## ]]`.
#
#
# Response:
#
# [[ ## answer ## ]]
# Noor will serve almond milk.
#
# [[ ## completed ## ]]

# %%
from typing import List, Literal
from pydantic import BaseModel


class Event(BaseModel):
    order: int
    actor: str
    action: str
    belief: str
    location: str | None = None

class ToMSignature(dspy.Signature):
    """Extract implicit reasoning needed for a ToM question, then answer."""
    story: str = dspy.InputField(desc="Short story/problem statement")

    world_facts: List[str] = dspy.OutputField()
    timeline: List[Event] = dspy.OutputField()
    bridging_rules: List[str] = dspy.OutputField()
    answer: str = dspy.OutputField()


class ToMExtractor(dspy.Module):
    def __init__(self):
        super().__init__()
        base = dspy.Predict(ToMSignature)

        def reward_fn(args, pred) -> float:
            score = 0.0
            # 1) final answer present
            if getattr(pred, "answer", "").strip():
                score += 1
    
            return score

        # Try up to N times; stop when score >= threshold
        self.extract = dspy.Refine(
            module=base,
            N=4,
            reward_fn=reward_fn,
            threshold=2.5,   # require any 2–3 of the checks to pass
        )

    def forward(self, story: str):
        return self.extract(story=story)



# 4) Run it on your ToM example
story = (
  "Noor is working as a barista at a busy coffee shop. Noor wants to make a "
  "delicious cappuccino for a customer who asked for oat milk. Noor grabs a "
  "milk pitcher and fills it with oat milk. "
  "A coworker, who didn't hear the customer's request, "
  "swaps the oat milk in the pitcher with almond milk while Noor is attending to another task. "
  "What will Noor do?"
)

extractor = ToMExtractor()
result = extractor(story=story)

# 5) Inspect the structured “reasoning steps”
print("World facts:", *result.world_facts, sep="\n- ")
print("\nTimeline:", *[e.model_dump() for e in result.timeline], sep="\n- ")
print("\nBridging rules:", *result.bridging_rules, sep="\n- ")
print("\nFinal answer:", result.answer)
# Out:
# World facts:
# - Noor is a barista at a coffee shop.
# - The customer asked for oat milk in their cappuccino.
# - The coworker didn't hear the customer's request.
# - Noor is attending to another task while the coworker swaps the milk.
#
# Timeline:
# - {'order': 1, 'actor': 'Noor', 'action': 'fill the milk pitcher with oat milk', 'belief': 'the customer wants oat milk', 'location': 'the coffee shop'}
# - {'order': 2, 'actor': 'the coworker', 'action': 'swap the oat milk with almond milk', 'belief': 'no specific belief', 'location': 'the coffee shop'}
# - {'order': 3, 'actor': 'Noor', 'action': 'make a cappuccino with the milk in the pitcher', 'belief': 'the milk in the pitcher is oat milk', 'location': 'the coffee shop'}
#
# Bridging rules:
# - If a customer asks for a specific type of milk, the barista should use that type of milk.
# - If a coworker swaps the milk without the barista's knowledge, the barista may not know what type of milk is in the pitcher.
#
# Final answer: Noor will likely notice that the milk in the pitcher is almond milk instead of oat milk and will ask the customer if they are okay with the substitution or will offer to remake the cappuccino with oat milk.
